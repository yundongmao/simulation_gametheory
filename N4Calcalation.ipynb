# %%
#size 3 graph 1
import sympy
from sympy import *
x1 = Symbol('x1')
x2 = Symbol('x2')
x3 = Symbol('x3')
x4 = Symbol('x4')
x5 = Symbol('x5')
x6 = Symbol('x6')
x7 = Symbol('x7')
x8 = Symbol('x8')
x9 = Symbol('x9')
x10 = Symbol('x10')
r = Symbol('r')
eqution = [(r+1)*x3+r*x4-(3*r+2)*x1]
eqution+=[r*x3-(2*r+1)*x2]
eqution+=[x2+r*x5-(r+1)*x3]
eqution+=[x1+(r+1)*x5-(r+2)*x4]
eqution+=[x3+(r+1)-(r+2)*x5]
print solve(eqution, [x1,x2,x3,x4,x5])
# Out:
# {x5: (r**2 + r + 1/2)/(r**2 + r + 1), x3: r*(2*r + 1)/(2*(r**2 + r + 1)), x4: (3*r**3 + 6*r**2 + 4*r + 1)/(3*r**3 + 7*r**2 + 7*r + 4), x1: r*(4*r**2 + 7*r + 3)/(2*(3*r**3 + 7*r**2 + 7*r + 4)), x2: r**2/(2*(r**2 + r + 1))}

# %%
x1: r*(4*r**2 + 7*r + 3)/(2*(3*r**3 + 7*r**2 + 7*r + 4))
x2: r**2/(2*(r**2 + r + 1))
x3: r*(2*r + 1)/(2*(r**2 + r + 1))
x4: (3*r**3 + 6*r**2 + 4*r + 1)/(3*r**3 + 7*r**2 + 7*r + 4)
x5: (r**2 + r + 1/2)/(r**2 + r + 1)

# %%
eqution=[x1-r*(4*r**2 + 7*r + 3)/(2*(3*r**3 + 7*r**2 + 7*r + 4))]
eqution+=[x2-r**2/(2*(r**2 + r + 1))]
eqution+=[x3*2-(x1+x2)]
print solve(eqution, [x1,x2,x3])
# Out:
# {x3: r*(7*r**2 + 11*r + 3)/(4*(3*r**3 + 7*r**2 + 7*r + 4)), x1: r*(4*r**2 + 7*r + 3)/(2*(3*r**3 + 7*r**2 + 7*r + 4)), x2: r**2/(2*(r**2 + r + 1))}

# %%
#size 3 graph 2
x1 = Symbol('x1')
x2 = Symbol('x2')
x3 = Symbol('x3')
x4 = Symbol('x4')
x5 = Symbol('x5')
x6 = Symbol('x6')
x7 = Symbol('x7')
x8 = Symbol('x8')
x9 = Symbol('x9')
x10 = Symbol('x10')
r = Symbol('r')
eqution=[4*x1-3*x3]
eqution+=[-2*(r+1)*x2+r*x3]
eqution+=[x2-(r+3)*x3+(r+2)*x5]
eqution+=[(2*r+1)*x2-(3*r+1)*x4+r*x5]
eqution+=[x4-2*(r+1)*x5+(2*r+1)]
print solve(eqution, [x1,x2,x3,x4,x5])
# Out:
# {x5: (6*r**2 + 11*r + 3)/(6*(r**2 + 2*r + 1)), x3: (r + 1/3)/(r + 1), x4: 2*r/(3*(r + 1)), x1: (3*r + 1)/(4*(r + 1)), x2: r*(3*r + 1)/(6*(r**2 + 2*r + 1))}

# %%
x1: (3*r + 1)/(4*(r + 1)) 
x2: r*(3*r + 1)/(6*(r**2 + 2*r + 1))
x3: (9*r**2 + 6*r + 1)/(16*(r**2 + 2*r + 1))

# %%
eqution=[x1-(3*r + 1)/(4*(r + 1))]
eqution+=[x2-r*(3*r + 1)/(6*(r**2 + 2*r + 1))]
eqution+=[x3*4-(x1+3*x2)]
print solve(eqution, [x1,x2,x3])
# Out:
# {x3: (9*r**2 + 6*r + 1)/(16*(r**2 + 2*r + 1)), x1: (3*r + 1)/(4*(r + 1)), x2: r*(3*r + 1)/(6*(r**2 + 2*r + 1))}

# %%
#size 4 graph 1
x1 = Symbol('x1')
x2 = Symbol('x2')
x3 = Symbol('x3')
x4 = Symbol('x4')
x5 = Symbol('x5')
x6 = Symbol('x6')
x7 = Symbol('x7')
x8 = Symbol('x8')
x9 = Symbol('x9')
x10 = Symbol('x10')
r = Symbol('r')
eqution=[-2*(r+1)*x1+r*x4]
eqution+=[-2*(2*r+1)*x2+(r+1)*x4+2*r*x5]
eqution+=[-(3*r*r+6*r+2)*x3+r*(r+1)*x5+r*(r+2)*x6]
eqution+=[-(r*r+3*r+1)*x4+(r+1)*x1+r*(r+2)*x8]
eqution+=[(r+2)*x2+2*(r+1)*x3-(2*r*r+9*r+8)*x5+(r+1)*(r+2)*x8+(r+1)*(r+2)*x9]
# eqution+=[2*x3+(r+1)*x9-(r+3)*x6]
eqution+=[(2*r+1)*x3+r*(r+1)*x9-(r*r+3*r+1)*x6]
eqution+=[(r+1)*(2*r+1)*x1+(r+1)*(2*r+1)*x3-(8*r*r+9*r+2)*x7+2*r*(r+1)*x8+r*(2*r+1)*x10]
eqution+=[(2*r+1)*x4+(r+1)*x7-(2*r*r+6*r+3)*x8+(r+1)*(2*r+1)]
eqution+=[x6-2*(r+1)*x9+(2*r+1)]
eqution+=[(r+1)*x6+2*x7-2*(r+2)*x10+(r+1)]
print solve(eqution,[x1,x2,x3,x4,x5,x6,x7,x8,x9,x10])
# Out:
# {x3: r*(64*r**7 + 469*r**6 + 1343*r**5 + 1998*r**4 + 1669*r**3 + 743*r**2 + 152*r + 10)/(96*r**8 + 808*r**7 + 2841*r**6 + 5638*r**5 + 7026*r**4 + 5638*r**3 + 2841*r**2 + 808*r + 96), x7: r*(76*r**7 + 580*r**6 + 1753*r**5 + 2801*r**4 + 2600*r**3 + 1405*r**2 + 408*r + 49)/(96*r**8 + 808*r**7 + 2841*r**6 + 5638*r**5 + 7026*r**4 + 5638*r**3 + 2841*r**2 + 808*r + 96), x10: (96*r**8 + 756*r**7 + 2410*r**6 + 4189*r**5 + 4395*r**4 + 2861*r**3 + 1136*r**2 + 253*r + 24)/(96*r**8 + 808*r**7 + 2841*r**6 + 5638*r**5 + 7026*r**4 + 5638*r**3 + 2841*r**2 + 808*r + 96), x9: (96*r**8 + 808*r**7 + 2809*r**6 + 5395*r**5 + 6321*r**4 + 4599*r**3 + 2011*r**2 + 481*r + 48)/(96*r**8 + 808*r**7 + 2841*r**6 + 5638*r**5 + 7026*r**4 + 5638*r**3 + 2841*r**2 + 808*r + 96), x2: r*(72*r**7 + 555*r**6 + 1705*r**5 + 2777*r**4 + 2631*r**3 + 1449*r**2 + 431*r + 52)/(96*r**8 + 808*r**7 + 2841*r**6 + 5638*r**5 + 7026*r**4 + 5638*r**3 + 2841*r**2 + 808*r + 96), x6: r*(96*r**7 + 744*r**6 + 2291*r**5 + 3742*r**4 + 3538*r**3 
# ...

# %%
# x1: r**2*(192*r**6 + 1404*r**5 + 3846*r**4 + 5162*r**3 + 3637*r**2 + 1254*r + 160)
#     /(384*r**8 + 3424*r**7 + 12724*r**6 + 26502*r**5 + 34325*r**4 + 28324*r**3 + 14451*r**2 + 4094*r + 480)
    
# x2: r*(288*r**7 + 2364*r**6 + 7738*r**5 + 13399*r**4 + 13394*r**3 + 7681*r**2 + 2308*r + 272)
#         /(384*r**8 + 3424*r**7 + 12724*r**6 + 26502*r**5 + 34325*r**4 + 28324*r**3 + 14451*r**2 + 4094*r + 480)
    
# x3: r*(256*r**7 + 2004*r**6 + 6182*r**5 + 10046*r**4 + 9409*r**3 + 5006*r**2 + 1381*r + 152)
#     /(384*r**8 + 3424*r**7 + 12724*r**6 + 26502*r**5 + 34325*r**4 + 28324*r**3 + 14451*r**2 + 4094*r + 480)

# x4: r*(1024*r**7 + 8136*r**6 + 25504*r**5 + 42006*r**4 + 39834*r**3 + 21622*r**2 + 6157*r + 696)
#         /(4*(384*r**8 + 3424*r**7 + 12724*r**6 + 26502*r**5 + 34325*r**4 + 28324*r**3 + 14451*r**2 + 4094*r + 480))

x1: r**2*(48*r**6 + 327*r**5 + 830*r**4 + 1039*r**3 + 705*r**2 + 243*r + 32)
    /(96*r**8 + 808*r**7 + 2841*r**6 + 5638*r**5 + 7026*r**4 + 5638*r**3 + 2841*r**2 + 808*r + 96)
x2: r*(72*r**7 + 555*r**6 + 1705*r**5 + 2777*r**4 + 2631*r**3 + 1449*r**2 + 431*r + 52)
    /(96*r**8 + 808*r**7 + 2841*r**6 + 5638*r**5 + 7026*r**4 + 5638*r**3 + 2841*r**2 + 808*r + 96)
x3: r*(64*r**7 + 469*r**6 + 1343*r**5 + 1998*r**4 + 1669*r**3 + 743*r**2 + 152*r + 10)
    /(96*r**8 + 808*r**7 + 2841*r**6 + 5638*r**5 + 7026*r**4 + 5638*r**3 + 2841*r**2 + 808*r + 96)
x4: r*(248*r**7 + 1820*r**6 + 5221*r**5 + 7812*r**4 + 6674*r**3 + 3178*r**2 + 767*r + 72)
    /(4*(96*r**8 + 808*r**7 + 2841*r**6 + 5638*r**5 + 7026*r**4 + 5638*r**3 + 2841*r**2 + 808*r + 96))

# %%
eqution=[r**2*(48*r**6 + 327*r**5 + 830*r**4 + 1039*r**3 + 705*r**2 + 243*r + 32)/(96*r**8 + 808*r**7 + 2841*r**6 + 5638*r**5 + 7026*r**4 + 5638*r**3 + 2841*r**2 + 808*r + 96)-x1]
eqution+=[r*(72*r**7 + 555*r**6 + 1705*r**5 + 2777*r**4 + 2631*r**3 + 1449*r**2 + 431*r + 52)/(96*r**8 + 808*r**7 + 2841*r**6 + 5638*r**5 + 7026*r**4 + 5638*r**3 + 2841*r**2 + 808*r + 96)-x2]
eqution+=[r*(64*r**7 + 469*r**6 + 1343*r**5 + 1998*r**4 + 1669*r**3 + 743*r**2 + 152*r + 10)/(96*r**8 + 808*r**7 + 2841*r**6 + 5638*r**5 + 7026*r**4 + 5638*r**3 + 2841*r**2 + 808*r + 96)-x3]
eqution+=[4*x4-(x1+x2+2*x3)]
print solve(eqution,[x1,x2,x3,x4])
# Out:
# {x3: r*(64*r**7 + 469*r**6 + 1343*r**5 + 1998*r**4 + 1669*r**3 + 743*r**2 + 152*r + 10)/(96*r**8 + 808*r**7 + 2841*r**6 + 5638*r**5 + 7026*r**4 + 5638*r**3 + 2841*r**2 + 808*r + 96), x4: r*(248*r**7 + 1820*r**6 + 5221*r**5 + 7812*r**4 + 6674*r**3 + 3178*r**2 + 767*r + 72)/(4*(96*r**8 + 808*r**7 + 2841*r**6 + 5638*r**5 + 7026*r**4 + 5638*r**3 + 2841*r**2 + 808*r + 96)), x1: r**2*(48*r**6 + 327*r**5 + 830*r**4 + 1039*r**3 + 705*r**2 + 243*r + 32)/(96*r**8 + 808*r**7 + 2841*r**6 + 5638*r**5 + 7026*r**4 + 5638*r**3 + 2841*r**2 + 808*r + 96), x2: r*(72*r**7 + 555*r**6 + 1705*r**5 + 2777*r**4 + 2631*r**3 + 1449*r**2 + 431*r + 52)/(96*r**8 + 808*r**7 + 2841*r**6 + 5638*r**5 + 7026*r**4 + 5638*r**3 + 2841*r**2 + 808*r + 96)}

# %%
#size 4 graph 2
x1 = Symbol('x1')
x2 = Symbol('x2')
x3 = Symbol('x3')
x4 = Symbol('x4')
x5 = Symbol('x5')
x6 = Symbol('x6')
x7 = Symbol('x7')
x8 = Symbol('x8')
x9 = Symbol('x9')
x10 = Symbol('x10')
r = Symbol('r')
eqution=[2*r*x2 - (3*r+1)*x1]
eqution+=[x1+r*x3-(r+1)*x2]
eqution+=[2*x2+(r+1)-(r+3)*x3]

print solve(eqution,[x1,x2,x3])
# Out:
# {x3: (3*r**2 + 2*r + 1)/(3*r**2 + 2*r + 3), x1: 2*r**2/(3*r**2 + 2*r + 3), x2: r*(3*r + 1)/(3*r**2 + 2*r + 3)}

# %%
x1: 2*r**2/(3*r**2 + 2*r + 3)

# %%
#size 5
x1 = Symbol('x1')
x2 = Symbol('x2')
x3 = Symbol('x3')
x4 = Symbol('x4')
x5 = Symbol('x5')
x6 = Symbol('x6')
x7 = Symbol('x7')
r = Symbol('r')
eqution=[2*r*(r+2)*x3+r*(r+1)*x4-(4*r*r+8*r+2)*x1]
eqution+=[2*r*x3-(3*r+2)*x2]
eqution+=[(r+2)*(2*r+1)*x1+2*(r+1)*(2*r+1)*x2+2*r*(r+2)*(r+1)*x6+r*(r+2)*(2*r+1)*x7-(4*r*r+13*r+4)*(r+1)*x3]
eqution+=[2*x1+(r+2)*x6-(r+4)*x4]
eqution+=[(2*r+1)*x2+2*r*x7-(4*r+1)*x5]
eqution+=[2*x3+(2*r+1)-(2*r+3)*x6]
eqution+=[2*(2*r+1)*x3+(r+1)*x5+(r+1)*(2*r+1)-2*(r*r+4*r+2)*x7]
print solve(eqution,[x1,x2,x3,x4,x5,x6,x7])
# Out:
# {x3: r*(12*r**3 + 41*r**2 + 31*r + 6)/(12*r**4 + 47*r**3 + 62*r**2 + 47*r + 12), x7: (48*r**6 + 352*r**5 + 877*r**4 + 903*r**3 + 461*r**2 + 119*r + 12)/(2*(24*r**6 + 178*r**5 + 477*r**4 + 622*r**3 + 477*r**2 + 178*r + 24)), x2: r**2*(8*r**2 + 22*r + 6)/(12*r**4 + 47*r**3 + 62*r**2 + 47*r + 12), x6: (12*r**4 + 47*r**3 + 56*r**2 + 25*r + 4)/(12*r**4 + 47*r**3 + 62*r**2 + 47*r + 12), x4: (24*r**6 + 166*r**5 + 394*r**4 + 383*r**3 + 176*r**2 + 41*r + 4)/(24*r**6 + 178*r**5 + 477*r**4 + 622*r**3 + 477*r**2 + 178*r + 24), x1: r*(36*r**5 + 237*r**4 + 493*r**3 + 341*r**2 + 77*r + 4)/(2*(24*r**6 + 178*r**5 + 477*r**4 + 622*r**3 + 477*r**2 + 178*r + 24)), x5: r*(20*r**5 + 137*r**4 + 301*r**3 + 239*r**2 + 83*r + 12)/(24*r**6 + 178*r**5 + 477*r**4 + 622*r**3 + 477*r**2 + 178*r + 24)}

# %%
x2: r**2*(8*r**2 + 22*r + 6)/(12*r**4 + 47*r**3 + 62*r**2 + 47*r + 12)
    
x1: r*(36*r**5 + 237*r**4 + 493*r**3 + 341*r**2 + 77*r + 4)
    /(2*(24*r**6 + 178*r**5 + 477*r**4 + 622*r**3 + 477*r**2 + 178*r + 24))
    
x3: r*(68*r**5 + 437*r**4 + 857*r**3 + 513*r**2 + 101*r + 4)
        /(4*(24*r**6 + 178*r**5 + 477*r**4 + 622*r**3 + 477*r**2 + 178*r + 24))

# %%
eqution=[r*(36*r**5 + 237*r**4 + 493*r**3 + 341*r**2 + 77*r + 4)/(2*(24*r**6 + 178*r**5 + 477*r**4 + 622*r**3 + 477*r**2 + 178*r + 24))-x1]
eqution+=[r**2*(8*r**2 + 22*r + 6)/(12*r**4 + 47*r**3 + 62*r**2 + 47*r + 12)-x2]
eqution+=[2*x3-(x1+x2)]

print solve(eqution,[x1,x2,x3])
# Out:
# {x3: r*(68*r**5 + 437*r**4 + 857*r**3 + 513*r**2 + 101*r + 4)/(4*(24*r**6 + 178*r**5 + 477*r**4 + 622*r**3 + 477*r**2 + 178*r + 24)), x1: r*(36*r**5 + 237*r**4 + 493*r**3 + 341*r**2 + 77*r + 4)/(2*(24*r**6 + 178*r**5 + 477*r**4 + 622*r**3 + 477*r**2 + 178*r + 24)), x2: r**2*(8*r**2 + 22*r + 6)/(12*r**4 + 47*r**3 + 62*r**2 + 47*r + 12)}

# %%
print 1024/(384*4.0)
print 172/(4*64.0)
print 40/64.0
print 92/(2*64.0)
# Out:
# 0.666666666667
# 0.671875
# 0.625
# 0.71875
