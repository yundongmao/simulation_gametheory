# %%
import sympy
from sympy import *
x1 = Symbol('x1')
x2 = Symbol('x2')
x3 = Symbol('x3')
x4 = Symbol('x4')
x5 = Symbol('x5')
x6 = Symbol('x6')
x7 = Symbol('x7')
x8 = Symbol('x8')
x9 = Symbol('x9')
x10 = Symbol('x10')
r = Symbol('r')
eqution = [(2*r+1)*x1-r*x2]
eqution+=[x1-(r+1)*x2+r*x3]
eqution+=[x2-(r+2)*x3+(r+1)]
print solve(eqution, [x1,x2,x3])
# Out:
# {x3: (r**2 + r + 1/2)/(r**2 + r + 1), x1: r**2/(2*(r**2 + r + 1)), x2: r*(2*r + 1)/(2*(r**2 + r + 1))}

# %%
x1 = Symbol('x1')
x2 = Symbol('x2')
x3 = Symbol('x3')
x4 = Symbol('x4')
x5 = Symbol('x5')
x6 = Symbol('x6')
x7 = Symbol('x7')
x8 = Symbol('x8')
x9 = Symbol('x9')
x10 = Symbol('x10')
r = Symbol('r')
eqution=[-2*(r+1)*x2+r*x3]
eqution+=[x2-(r+3)*x3+(r+2)*x5]
eqution+=[(2*r+1)*x2-(3*r+1)*x4+r*x5]
eqution+=[x4-2*(r+1)*x5+(2*r+1)]
print solve(eqution, [x2,x3,x4,x5])
# Out:
# {x5: (6*r**2 + 11*r + 3)/(6*(r**2 + 2*r + 1)), x3: (r + 1/3)/(r + 1), x4: 2*r/(3*(r + 1)), x2: r*(3*r + 1)/(6*(r**2 + 2*r + 1))}

# %%
x1 = Symbol('x1')
x2 = Symbol('x2')
x3 = Symbol('x3')
x4 = Symbol('x4')
x5 = Symbol('x5')
x6 = Symbol('x6')
x7 = Symbol('x7')
x8 = Symbol('x8')
x9 = Symbol('x9')
x10 = Symbol('x10')
r = Symbol('r')
eqution=[-2*(r+1)*x1+r*x4]
eqution+=[-2*(2*r+1)*x2+(r+1)*x4+2*r*x5]
eqution+=[-(3*r*r+6*r+2)*x3+r*(r+1)*x5+r*(r+2)*x6]
eqution+=[-(r*r+3*r+1)*x4+(r+1)*x1+r*(r+2)*x8]
eqution+=[(r+2)*x2+2*(r+1)*x3-(2*r*r+9*r+8)*x5+(r+1)*(r+2)*x8+(r+1)*(r+2)*x9]
eqution+=[2*x3+(r+1)*x9-(r+3)*x6]
eqution+=[(r+1)*(2*r+1)*x1+(r+1)*(2*r+1)*x3-(8*r*r+9*r+2)*x7+2*r*(r+1)*x8+r*(2*r+1)*x10]
eqution+=[(2*r+1)*x4+(r+1)*x7-(2*r*r+6*r+3)*x8+(r+1)*(2*r+1)]
eqution+=[x6-2*(r+1)*x9+(2*r+1)]
eqution+=[(r+1)*x6+2*x7-2*(r+2)*x10+(r+1)]
print solve(eqution,[x1,x2,x3,x4,x5,x6,x7,x8,x9,x10])
# Out:
# {x3: r*(256*r**7 + 2004*r**6 + 6182*r**5 + 10046*r**4 + 9409*r**3 + 5006*r**2 + 1381*r + 152)/(384*r**8 + 3424*r**7 + 12724*r**6 + 26502*r**5 + 34325*r**4 + 28324*r**3 + 14451*r**2 + 4094*r + 480), x7: r*(304*r**7 + 2472*r**6 + 7996*r**5 + 13688*r**4 + 13571*r**3 + 7810*r**2 + 2412*r + 308)/(384*r**8 + 3424*r**7 + 12724*r**6 + 26502*r**5 + 34325*r**4 + 28324*r**3 + 14451*r**2 + 4094*r + 480), x10: (384*r**8 + 3216*r**7 + 10960*r**6 + 20410*r**5 + 22927*r**4 + 15914*r**3 + 6653*r**2 + 1523*r + 144)/(384*r**8 + 3424*r**7 + 12724*r**6 + 26502*r**5 + 34325*r**4 + 28324*r**3 + 14451*r**2 + 4094*r + 480), x9: (384*r**8 + 3424*r**7 + 12596*r**6 + 25530*r**5 + 31505*r**4 + 24168*r**3 + 11131*r**2 + 2786*r + 288)/(384*r**8 + 3424*r**7 + 12724*r**6 + 26502*r**5 + 34325*r**4 + 28324*r**3 + 14451*r**2 + 4094*r + 480), x2: r*(288*r**7 + 2364*r**6 + 7738*r**5 + 13399*r**4 + 13394*r**3 + 7681*r**2 + 2308*r + 272)/(384*r**8 + 3424*r**7 + 12724*r**6 + 26502*r**5 + 34325*r**4 + 28324*r**3 + 14451*r**2 + 4094*r + 480), x6: (384*r**8 + 3168*r**7 + 10524*r**6 + 18918*r**5 + 20373*r**4 + 13372*r**3 + 5195*r**2 + 1094*r + 96)/(384*r**8 + 3424*r**7 + 12724*r**6 + 26502*r**5 + 34325*r**4 + 28324*r**3 + 14451*r**2 + 4094*r + 480), x4: 2*r*(192*r**7 + 1596*r**6 + 5250*r**5 + 9008*r**4 + 8799*r**3 + 4891*r**2 + 1414*r + 160)/(384*r**8 + 3424*r**7 + 12724*r**6 + 26502*r**5 + 34325*r**4 + 28324*r**3 + 14451*r**2 + 4094*r + 480), x1: r**2*(192*r**6 + 1404*r**5 + 3846*r**4 + 5162*r**3 + 3637*r**2 + 1254*r + 160)/(384*r**8 + 3424*r**7 + 12724*r**6 + 26502*r**5 + 34325*r**4 + 28324*r**3 + 14451*r**2 + 4094*r + 480), x8: (384*r**8 + 3384*r**7 + 12096*r**6 + 23266*r**5 + 26606*r**4 + 18581*r**3 + 7719*r**2 + 1734*r + 160)/(384*r**8 + 3424*r**7 + 12724*r**6 + 26502*r**5 + 34325*r**4 + 28324*r**3 + 14451*r**2 + 4094*r + 480), x5: 2*(192*r**8 + 1614*r**7 + 5497*r**6 + 10139*r**5 + 11190*r**4 + 7533*r**3 + 2996*r**2 + 639*r + 56)/(384*r**8 + 3424*r**7 + 12724*r**6 + 26502*r**5 + 34325*r**4 + 28324*r**3 + 14451*r**2 + 4094*r + 480)}

# %%
x1 = Symbol('x1')
x2 = Symbol('x2')
x3 = Symbol('x3')
x4 = Symbol('x4')
x5 = Symbol('x5')
x6 = Symbol('x6')
x7 = Symbol('x7')
r = Symbol('r')
eqution=[2*r*(r+2)*x3+r*(r+1)*x4-(4*r*r+8*r+2)*x1]
eqution+=[2*r*x3-(3*r+2)*x2]
eqution+=[(r+2)*(2*r+1)*x1+2*(r+1)*(2*r+1)*x2+2*r*(r+2)*(r+1)*x6+r*(r+2)*(2*r+1)*x7-(4*r*r+13*r+4)*(r+1)*x3]
eqution+=[2*x1+(r+2)*x6-(r+4)*x4]
eqution+=[(2*r+1)*x2+2*r*x7-(4*r+1)*x5]
eqution+=[2*x3+(2*r+1)*x8-(2*r+3)*x6]
eqution+=[2*x3+(r+1)*x5+(r+1)*x8-2*(r+2)*x7]
print solve(eqution,[x1,x2,x3,x4,x5,x6,x7])
# Out:
# {x3: r*x8*(120*r**5 + 794*r**4 + 1685*r**3 + 1349*r**2 + 434*r + 48)/(2*(64*r**6 + 460*r**5 + 1185*r**4 + 1490*r**3 + 1078*r**2 + 380*r + 48)), x7: x8*(56*r**6 + 390*r**5 + 916*r**4 + 912*r**3 + 461*r**2 + 119*r + 12)/(64*r**6 + 460*r**5 + 1185*r**4 + 1490*r**3 + 1078*r**2 + 380*r + 48), x2: r**2*x8*(40*r**4 + 238*r**3 + 403*r**2 + 181*r + 24)/(64*r**6 + 460*r**5 + 1185*r**4 + 1490*r**3 + 1078*r**2 + 380*r + 48), x6: x8*(64*r**6 + 456*r**5 + 1128*r**4 + 1233*r**3 + 648*r**2 + 164*r + 16)/(64*r**6 + 460*r**5 + 1185*r**4 + 1490*r**3 + 1078*r**2 + 380*r + 48), x4: x8*(64*r**6 + 420*r**5 + 935*r**4 + 867*r**3 + 383*r**2 + 86*r + 8)/(64*r**6 + 460*r**5 + 1185*r**4 + 1490*r**3 + 1078*r**2 + 380*r + 48), x1: r*x8*(92*r**5 + 575*r**4 + 1118*r**3 + 737*r**2 + 158*r + 8)/(2*(64*r**6 + 460*r**5 + 1185*r**4 + 1490*r**3 + 1078*r**2 + 380*r + 48)), x5: r*x8*(48*r**5 + 312*r**4 + 641*r**3 + 487*r**2 + 166*r + 24)/(64*r**6 + 460*r**5 + 1185*r**4 + 1490*r**3 + 1078*r**2 + 380*r + 48)}
